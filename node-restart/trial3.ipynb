# %%
import requests
import time
import json
import subprocess
import logging

logging.basicConfig(
    filename="curl_logs.txt", level=logging.INFO, format="%(asctime)s - %(message)s"
)


def main():
    url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
    headers = {"Content-Type": "application/json"}

    payload = {
        "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
        "password": "SuhasDevmane",
    }

    response = requests.post(url, json=payload, headers=headers)

    if response.status_code == 200:
        # Authentication successful
        token = response.json().get("token")
        # print("JWT_Token:", token)
    else:
        logging.error("Authentication failed. Status Code:", response.status_code)
        logging.error("Response:", response.text)

    # Get current timestamp in Unix format with milliseconds
    current_timestamp = int(time.time() * 1000)
    # print("Current timestamp (Unix format with milliseconds):", current_timestamp)
    device_ids = [
        "70ad22a0-b82c-11ed-b196-bb47e24272bc",
        "75d29440-b82c-11ed-b196-bb47e24272bc",
        "7b717ba0-b82c-11ed-b196-bb47e24272bc",
        "a673eb80-b82c-11ed-b196-bb47e24272bc",
        "83456b70-b82c-11ed-b196-bb47e24272bc",
        "b96d6720-b82c-11ed-b196-bb47e24272bc",
        "be98a520-b82c-11ed-b196-bb47e24272bc",
        "c3110de0-b82c-11ed-b196-bb47e24272bc",
        "c950f030-b82c-11ed-b196-bb47e24272bc",
        "cfddba00-b82c-11ed-b196-bb47e24272bc",
        "278505c0-0f7a-11ee-bf90-a16a1a9e1e0a",
        "d9576a90-b82c-11ed-b196-bb47e24272bc",
        "de18ea40-b82c-11ed-b196-bb47e24272bc",
        "f57a1560-7cf3-11ee-94bc-d389020903a3",
        "508d1b60-57eb-11ee-8714-19d56ba0c4fd",
        "86c63bd0-57f0-11ee-8714-19d56ba0c4fd",
        "3efd82d0-7cf4-11ee-94bc-d389020903a3",
        "f583bc50-57e6-11ee-8714-19d56ba0c4fd",
        "9458c560-0f75-11ee-bf90-a16a1a9e1e0a",
        "cbc851c0-57ee-11ee-8714-19d56ba0c4fd",
        "2ae959b0-53c6-11ee-8714-19d56ba0c4fd",
        "351b0eb0-57ef-11ee-8714-19d56ba0c4fd",
        "0f96bed0-b82d-11ed-b196-bb47e24272bc",
        "13e642d0-b82d-11ed-b196-bb47e24272bc",
        "18a159e0-b82d-11ed-b196-bb47e24272bc",
        "fef50770-57f1-11ee-8714-19d56ba0c4fd",
        "2a5d9a90-b82d-11ed-b196-bb47e24272bc",
        "99c6a3b0-b82b-11ed-b196-bb47e24272bc",
        "51f2d170-57e1-11ee-8714-19d56ba0c4fd",
        "9c563630-0f75-11ee-bf90-a16a1a9e1e0a",
        "391303e0-b82d-11ed-b196-bb47e24272bc",
        "3d3a3f60-b82d-11ed-b196-bb47e24272bc",
        "a83a46c0-7cf4-11ee-94bc-d389020903a3",
        "4665a8e0-b82d-11ed-b196-bb47e24272bc",
    ]
    access_token = token
    base_url = "https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE"

    # List to store responses for each device
    all_responses = []

    for device_id in device_ids:
        url = f"{base_url}/{device_id}/values/timeseries?keys=ip_address"
        headers = {
            "Content-Type": "application/json",
            "X-Authorization": f"Bearer {access_token}",
        }
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            all_responses.append(data)
        else:
            logging.error(
                f"Failed to get data for device {device_id}. Status Code: {response.status_code}"
            )
            logging.error(response.text)

        current_timestamp = int(
            time.time() * 1000
        )  # Get current timestamp in milliseconds
        results = []
        for info in data:
            ts = info.get("ts", 0)
            value = info.get("value")
            time_diff = (
                current_timestamp - ts
            ) / 1000  # Convert milliseconds to seconds

            status = "yes" if time_diff > 150 else "no"
            if value is None:
                status = "no"

            result = {
                "value": value,
                "ts": ts,
                "current-ts": current_timestamp,
                "status": status,
            }
            results.append(result)

            if status == "yes":
                ip_address = result["value"]
                url = (
                    "http://probable-goshawk-accurately.ngrok-free.app/device_activity"
                )
                payload = {"ip_address": {ip_address}}
                response = requests.post(
                    url, json=payload, headers=headers
                )  # Print the response
                time.sleep(5)
                print(response.text)
                print(f"sensor node is offline with {ip_address} and restarted")
                logging.info(f"{ip_address} is restarted")
        return results


if __name__ == "__main__":
    while True:
        main()
        time.sleep(15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 133
#     131 if __name__ == "__main__":
#     132     while True:
# --> 133         main()
#     134         time.sleep(15)
#
# Cell In[1], line 98, in main()
#      96 results = []
#      97 for info in data:
# ---> 98     ts = info.get("ts", 0)
#      99     value = info.get("value")
#     100     time_diff = (
#     101         current_timestamp - ts
#     102     ) / 1000  # Convert milliseconds to seconds
#
# AttributeError: 'str' object has no attribute 'get'

# %%
import requests
import time
import json
import subprocess
import logging

logging.basicConfig(
    filename="curl_logs.txt", level=logging.INFO, format="%(asctime)s - %(message)s"
)


def main():
    url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
    headers = {"Content-Type": "application/json"}

    payload = {
        "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
        "password": "SuhasDevmane",
    }

    response = requests.post(url, json=payload, headers=headers)

    if response.status_code == 200:
        # Authentication successful
        token = response.json().get("token")
        # print("JWT_Token:", token)
    else:
        logging.error("Authentication failed. Status Code:", response.status_code)
        logging.error("Response:", response.text)
        return  # Exit the function if authentication fails

    # Get current timestamp in Unix format with milliseconds
    current_timestamp = int(time.time() * 1000)
    # print("Current timestamp (Unix format with milliseconds):", current_timestamp)
    device_ids = [
        "70ad22a0-b82c-11ed-b196-bb47e24272bc",
        "75d29440-b82c-11ed-b196-bb47e24272bc",
        "7b717ba0-b82c-11ed-b196-bb47e24272bc",
        "a673eb80-b82c-11ed-b196-bb47e24272bc",
        "83456b70-b82c-11ed-b196-bb47e24272bc",
        "b96d6720-b82c-11ed-b196-bb47e24272bc",
        "be98a520-b82c-11ed-b196-bb47e24272bc",
        "c3110de0-b82c-11ed-b196-bb47e24272bc",
        "c950f030-b82c-11ed-b196-bb47e24272bc",
        "cfddba00-b82c-11ed-b196-bb47e24272bc",
        "278505c0-0f7a-11ee-bf90-a16a1a9e1e0a",
        "d9576a90-b82c-11ed-b196-bb47e24272bc",
        "de18ea40-b82c-11ed-b196-bb47e24272bc",
        "f57a1560-7cf3-11ee-94bc-d389020903a3",
        "508d1b60-57eb-11ee-8714-19d56ba0c4fd",
        "86c63bd0-57f0-11ee-8714-19d56ba0c4fd",
        "3efd82d0-7cf4-11ee-94bc-d389020903a3",
        "f583bc50-57e6-11ee-8714-19d56ba0c4fd",
        "9458c560-0f75-11ee-bf90-a16a1a9e1e0a",
        "cbc851c0-57ee-11ee-8714-19d56ba0c4fd",
        "2ae959b0-53c6-11ee-8714-19d56ba0c4fd",
        "351b0eb0-57ef-11ee-8714-19d56ba0c4fd",
        "0f96bed0-b82d-11ed-b196-bb47e24272bc",
        "13e642d0-b82d-11ed-b196-bb47e24272bc",
        "18a159e0-b82d-11ed-b196-bb47e24272bc",
        "fef50770-57f1-11ee-8714-19d56ba0c4fd",
        "2a5d9a90-b82d-11ed-b196-bb47e24272bc",
        "99c6a3b0-b82b-11ed-b196-bb47e24272bc",
        "51f2d170-57e1-11ee-8714-19d56ba0c4fd",
        "9c563630-0f75-11ee-bf90-a16a1a9e1e0a",
        "391303e0-b82d-11ed-b196-bb47e24272bc",
        "3d3a3f60-b82d-11ed-b196-bb47e24272bc",
        "a83a46c0-7cf4-11ee-94bc-d389020903a3",
        "4665a8e0-b82d-11ed-b196-bb47e24272bc",
    ]
    access_token = token
    key_to_fetch = ["ip_address"]
    base_url = "https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE"

    # List to store responses for each device

    for device_id in device_ids:
        url = f"{base_url}/{device_id}/values/timeseries?keys={','.join(key_to_fetch)}"
        headers = {
            "Content-Type": "application/json",
            "X-Authorization": f"Bearer {access_token}",
        }
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            # print(data)
        else:
            logging.error(
                f"Failed to get data for device {device_id}. Status Code: {response.status_code}"
            )
            logging.error(response.text)
            continue  # Skip to the next device if there's an error
        current_timestamp = int(
            time.time() * 1000
        )  # Get current timestamp in milliseconds
        results = []
        # Iterate over the list associated with the key "ip_address"
        for ip_info in data.get("ip_address", []):
            # Access the 'ts' and 'value' keys for each dictionary in the list
            ts = ip_info.get("ts", 0)
            value = ip_info.get("value")
            # print("Timestamp:", ts)
            # print("Value:", value)
            time_diff = (
                current_timestamp - ts
            ) / 1000  # Convert milliseconds to seconds

            status = "yes" if time_diff > 120 else "no"
            if value is None:
                status = "no"

            result = {
                "value": value,
                "ts": ts,
                "current-ts": current_timestamp,
                "status": status,
            }
            results.append(result)
            print(results)
            for result in results:
                if result["status"] == "yes":
                    ip_address = result["value"]
                    url = "http://probable-goshawk-accurately.ngrok-free.app/device_activity"
                    payload = {
                        "ip_address": ip_address
                    }  # Removed unnecessary curly braces around ip_address
                    headers = {
                        "Content-Type": "application/json"
                    }  # Assuming you have headers defined somewhere
                    response = requests.post(url, json=payload, headers=headers)
                    time.sleep(5)
                    print(response.text)
                    print(f"Sensor node is offline with {ip_address} and restarted")
                    logging.info(f"{ip_address} is restarted")
            time.sleep(5)
        # return results


if __name__ == "__main__":
    while True:
        main()
# Out:
# [{'value': None, 'ts': 1713483122391, 'current-ts': 1713483123168, 'status': 'no'}]
# [{'value': None, 'ts': 1713483124490, 'current-ts': 1713483125275, 'status': 'no'}]
# [{'value': None, 'ts': 1713483126600, 'current-ts': 1713483127377, 'status': 'no'}]
# [{'value': None, 'ts': 1713483128694, 'current-ts': 1713483129474, 'status': 'no'}]
# [{'value': None, 'ts': 1713483130802, 'current-ts': 1713483131580, 'status': 'no'}]
# [{'value': None, 'ts': 1713483132903, 'current-ts': 1713483133683, 'status': 'no'}]
# [{'value': None, 'ts': 1713483134996, 'current-ts': 1713483135774, 'status': 'no'}]
# [{'value': None, 'ts': 1713483137087, 'current-ts': 1713483137865, 'status': 'no'}]
# [{'value': None, 'ts': 1713483139191, 'current-ts': 1713483139969, 'status': 'no'}]
# [{'value': None, 'ts': 1713483141290, 'current-ts': 1713483142068, 'status': 'no'}]
# [{'value': None, 'ts': 1713483143393, 'current-ts': 1713483144171, 'status': 'no'}]
# [{'value': None, 'ts': 1713483145496, 'current-ts': 1713483146275, 'status': 'no'}]
# [{'value': None, 'ts': 1713483147598, 'current-ts': 1713483148375, 'status': 'no'}]
# [{'value': None, 'ts': 1713483149714, 'current-ts': 1713483150498, 'status': 'no'}]
# [{'value': None, 'ts': 1713483151812, 'current-ts': 1713483152590, 'status': 'no'}]
# [{'value': None, 'ts': 1713483153908, 'current-ts': 1713483154687, 'status': 'no'}]
# [{'value': None, 'ts': 1713483156015, 'current-ts': 1713483156794, 'status': 'no'}]
# [{'value': '10.10.227.56', 'ts': 1713483066218, 'current-ts': 1713483158896, 'status': 'no'}]
# [{'value': None, 'ts': 1713483160226, 'current-ts': 1713483161002, 'status': 'no'}]
# [{'value': None, 'ts': 1713483162326, 'current-ts': 1713483163106, 'status': 'no'}]
# [{'value': '10.10.182.13', 'ts': 1713483159147, 'current-ts': 1713483165203, 'status': 'no'}]
# [{'value': None, 'ts': 1713483166528, 'current-ts': 1713483167306, 'status': 'no'}]
# [{'value': None, 'ts': 1713483168626, 'current-ts': 1713483169403, 'status': 'no'}]
# [{'value': None, 'ts': 1713483170732, 'current-ts': 1713483171511, 'status': 'no'}]
# [{'value': None, 'ts': 1713483172828, 'current-ts': 1713483173607, 'status': 'no'}]
# [{'value': None, 'ts': 1713483174922, 'current-ts': 1713483175701, 'status': 'no'}]
# [{'value': None, 'ts': 1713483177015, 'current-ts': 1713483177792, 'status': 'no'}]
# [{'value': None, 'ts': 1713483179109, 'current-ts': 1713483179887, 'status': 'no'}]
# [{'value': None, 'ts': 1713483181212, 'current-ts': 1713483181991, 'status': 'no'}]
# [{'value': None, 'ts': 1713483183307, 'current-ts': 1713483184084, 'status': 'no'}]
# [{'value': None, 'ts': 1713483185410, 'current-ts': 1713483186187, 'status': 'no'}]
# [{'value': None, 'ts': 1713483187516, 'current-ts': 1713483188295, 'status': 'no'}]
# [{'value': None, 'ts': 1713483189621, 'current-ts': 1713483190399, 'status': 'no'}]
# [{'value': None, 'ts': 1713483191715, 'current-ts': 1713483192494, 'status': 'no'}]
# [{'value': None, 'ts': 1713483194012, 'current-ts': 1713483194790, 'status': 'no'}]
# [{'value': None, 'ts': 1713483196098, 'current-ts': 1713483196877, 'status': 'no'}]
# [{'value': None, 'ts': 1713483198189, 'current-ts': 1713483198968, 'status': 'no'}]
# [{'value': None, 'ts': 1713483200284, 'current-ts': 1713483201063, 'status': 'no'}]
# [{'value': None, 'ts': 1713483202375, 'current-ts': 1713483203153, 'status': 'no'}]
# [{'value': None, 'ts': 1713483204473, 'current-ts': 1713483205250, 'status': 'no'}]
# [{'value': None, 'ts': 1713483206568, 'current-ts': 1713483207346, 'status': 'no'}]
# [{'value': None, 'ts': 1713483208665, 'current-ts': 1713483209444, 'status': 'no'}]
# [{'value': None, 'ts': 1713483210774, 'current-ts': 1713483211551, 'status': 'no'}]
# [{'value': None, 'ts': 1713483212879, 'current-ts': 1713483213657, 'status': 'no'}]
# [{'value': None, 'ts': 1713483214982, 'current-ts': 1713483215760, 'status': 'no'}]
# [{'value': None, 'ts': 1713483217085, 'current-ts': 1713483217864, 'status': 'no'}]
# [{'value': None, 'ts': 1713483219184, 'current-ts': 1713483219963, 'status': 'no'}]
# [{'value': None, 'ts': 1713483221274, 'current-ts': 1713483222053, 'status': 'no'}]
# [{'value': None, 'ts': 1713483223375, 'current-ts': 1713483224152, 'status': 'no'}]
# [{'value': None, 'ts': 1713483225478, 'current-ts': 1713483226258, 'status': 'no'}]
# [{'value': None, 'ts': 1713483227582, 'current-ts': 1713483228362, 'status': 'no'}]
# [{'value': '10.10.227.56', 'ts': 1713483066218, 'current-ts': 1713483230462, 'status': 'yes'}]
# {
#   "message": "Device restarted with 10.10.227.56"
# }
#
# Sensor node is offline with 10.10.227.56 and restarted
# [{'value': None, 'ts': 1713483247220, 'current-ts': 1713483247998, 'status': 'no'}]
# [{'value': None, 'ts': 1713483249314, 'current-ts': 1713483250092, 'status': 'no'}]
# [{'value': '10.10.182.13', 'ts': 1713483247107, 'current-ts': 1713483252185, 'status': 'no'}]
# [{'value': None, 'ts': 1713483253506, 'current-ts': 1713483254285, 'status': 'no'}]
# [{'value': None, 'ts': 1713483255615, 'current-ts': 1713483256396, 'status': 'no'}]
# [{'value': None, 'ts': 1713483257723, 'current-ts': 1713483258502, 'status': 'no'}]
# [{'value': None, 'ts': 1713483259825, 'current-ts': 1713483260604, 'status': 'no'}]
# [{'value': None, 'ts': 1713483261928, 'current-ts': 1713483262706, 'status': 'no'}]
# [{'value': None, 'ts': 1713483264024, 'current-ts': 1713483264802, 'status': 'no'}]
# [{'value': None, 'ts': 1713483266134, 'current-ts': 1713483266912, 'status': 'no'}]
# [{'value': None, 'ts': 1713483268224, 'current-ts': 1713483269001, 'status': 'no'}]
# [{'value': None, 'ts': 1713483270318, 'current-ts': 1713483271098, 'status': 'no'}]
# [{'value': None, 'ts': 1713483272421, 'current-ts': 1713483273200, 'status': 'no'}]
# [{'value': None, 'ts': 1713483274515, 'current-ts': 1713483275295, 'status': 'no'}]
# [{'value': None, 'ts': 1713483276621, 'current-ts': 1713483277400, 'status': 'no'}]
# [{'value': None, 'ts': 1713483278731, 'current-ts': 1713483279509, 'status': 'no'}]
# [{'value': None, 'ts': 1713483281127, 'current-ts': 1713483281905, 'status': 'no'}]
# [{'value': None, 'ts': 1713483283232, 'current-ts': 1713483284017, 'status': 'no'}]
# [{'value': None, 'ts': 1713483285332, 'current-ts': 1713483286111, 'status': 'no'}]
# [{'value': None, 'ts': 1713483287431, 'current-ts': 1713483288209, 'status': 'no'}]
# [{'value': None, 'ts': 1713483289520, 'current-ts': 1713483290299, 'status': 'no'}]
# [{'value': None, 'ts': 1713483291612, 'current-ts': 1713483292391, 'status': 'no'}]
# [{'value': None, 'ts': 1713483293704, 'current-ts': 1713483294483, 'status': 'no'}]
# [{'value': None, 'ts': 1713483295804, 'current-ts': 1713483296583, 'status': 'no'}]
# [{'value': None, 'ts': 1713483297900, 'current-ts': 1713483298680, 'status': 'no'}]
# [{'value': None, 'ts': 1713483300001, 'current-ts': 1713483300779, 'status': 'no'}]
# [{'value': None, 'ts': 1713483302104, 'current-ts': 1713483302882, 'status': 'no'}]
# [{'value': None, 'ts': 1713483304205, 'current-ts': 1713483304984, 'status': 'no'}]
# [{'value': None, 'ts': 1713483306300, 'current-ts': 1713483307080, 'status': 'no'}]
# [{'value': None, 'ts': 1713483308391, 'current-ts': 1713483309171, 'status': 'no'}]
# [{'value': None, 'ts': 1713483310494, 'current-ts': 1713483311272, 'status': 'no'}]
# [{'value': None, 'ts': 1713483312588, 'current-ts': 1713483313366, 'status': 'no'}]
# [{'value': None, 'ts': 1713483314681, 'current-ts': 1713483315460, 'status': 'no'}]
# [{'value': '10.10.227.56', 'ts': 1713483066218, 'current-ts': 1713483317581, 'status': 'yes'}]
# {
#   "message": "Device restarted with 10.10.227.56"
# }
#
# Sensor node is offline with 10.10.227.56 and restarted
# [{'value': None, 'ts': 1713483334488, 'current-ts': 1713483335281, 'status': 'no'}]
# [{'value': None, 'ts': 1713483336610, 'current-ts': 1713483337389, 'status': 'no'}]
# [{'value': '10.10.182.13', 'ts': 1713483257961, 'current-ts': 1713483339495, 'status': 'no'}]
# [{'value': None, 'ts': 1713483340808, 'current-ts': 1713483341588, 'status': 'no'}]
# [{'value': None, 'ts': 1713483342909, 'current-ts': 1713483343688, 'status': 'no'}]
# [{'value': None, 'ts': 1713483345004, 'current-ts': 1713483345784, 'status': 'no'}]
# [{'value': None, 'ts': 1713483347104, 'current-ts': 1713483347883, 'status': 'no'}]
# [{'value': None, 'ts': 1713483349211, 'current-ts': 1713483349989, 'status': 'no'}]
# [{'value': None, 'ts': 1713483351305, 'current-ts': 1713483352084, 'status': 'no'}]
# [{'value': None, 'ts': 1713483353407, 'current-ts': 1713483354185, 'status': 'no'}]
# [{'value': None, 'ts': 1713483355511, 'current-ts': 1713483356290, 'status': 'no'}]
# [{'value': None, 'ts': 1713483357606, 'current-ts': 1713483358383, 'status': 'no'}]
# [{'value': None, 'ts': 1713483359713, 'current-ts': 1713483360492, 'status': 'no'}]
# [{'value': None, 'ts': 1713483361806, 'current-ts': 1713483362585, 'status': 'no'}]
# [{'value': None, 'ts': 1713483363927, 'current-ts': 1713483364707, 'status': 'no'}]
# [{'value': None, 'ts': 1713483366024, 'current-ts': 1713483366802, 'status': 'no'}]
# [{'value': None, 'ts': 1713483368322, 'current-ts': 1713483369100, 'status': 'no'}]
# [{'value': None, 'ts': 1713483370425, 'current-ts': 1713483371205, 'status': 'no'}]
# [{'value': None, 'ts': 1713483372525, 'current-ts': 1713483373303, 'status': 'no'}]
# [{'value': None, 'ts': 1713483374627, 'current-ts': 1713483375406, 'status': 'no'}]
# [{'value': None, 'ts': 1713483376728, 'current-ts': 1713483377508, 'status': 'no'}]
# [{'value': None, 'ts': 1713483378837, 'current-ts': 1713483379615, 'status': 'no'}]
# [{'value': None, 'ts': 1713483380939, 'current-ts': 1713483381718, 'status': 'no'}]
# [{'value': None, 'ts': 1713483383041, 'current-ts': 1713483383818, 'status': 'no'}]
# [{'value': None, 'ts': 1713483385148, 'current-ts': 1713483385928, 'status': 'no'}]
# [{'value': None, 'ts': 1713483387241, 'current-ts': 1713483388019, 'status': 'no'}]
# [{'value': None, 'ts': 1713483389335, 'current-ts': 1713483390114, 'status': 'no'}]
# [{'value': None, 'ts': 1713483391424, 'current-ts': 1713483392202, 'status': 'no'}]
# [{'value': None, 'ts': 1713483393521, 'current-ts': 1713483394299, 'status': 'no'}]
# [{'value': None, 'ts': 1713483395616, 'current-ts': 1713483396394, 'status': 'no'}]
# [{'value': None, 'ts': 1713483397702, 'current-ts': 1713483398481, 'status': 'no'}]
# [{'value': None, 'ts': 1713483399805, 'current-ts': 1713483400584, 'status': 'no'}]
# [{'value': None, 'ts': 1713483401912, 'current-ts': 1713483402693, 'status': 'no'}]
# [{'value': '10.10.227.56', 'ts': 1713483066218, 'current-ts': 1713483404794, 'status': 'yes'}]
# {
#   "message": "Device restarted with 10.10.227.56"
# }
#
# Sensor node is offline with 10.10.227.56 and restarted
# [{'value': None, 'ts': 1713483421681, 'current-ts': 1713483422459, 'status': 'no'}]
# [{'value': None, 'ts': 1713483423774, 'current-ts': 1713483424553, 'status': 'no'}]
# [{'value': '10.10.182.13', 'ts': 1713483257961, 'current-ts': 1713483426653, 'status': 'yes'}]
# {
#   "message": "Device restarted with 10.10.182.13"
# }
#
# Sensor node is offline with 10.10.182.13 and restarted
# [{'value': None, 'ts': 1713483443648, 'current-ts': 1713483444427, 'status': 'no'}]
# [{'value': None, 'ts': 1713483445751, 'current-ts': 1713483446530, 'status': 'no'}]
# [{'value': None, 'ts': 1713483447855, 'current-ts': 1713483448633, 'status': 'no'}]
# [{'value': None, 'ts': 1713483449949, 'current-ts': 1713483450730, 'status': 'no'}]
# [{'value': None, 'ts': 1713483452051, 'current-ts': 1713483452830, 'status': 'no'}]
# [{'value': None, 'ts': 1713483454148, 'current-ts': 1713483454926, 'status': 'no'}]
# [{'value': None, 'ts': 1713483456257, 'current-ts': 1713483457035, 'status': 'no'}]
# [{'value': None, 'ts': 1713483458358, 'current-ts': 1713483459135, 'status': 'no'}]
# [{'value': None, 'ts': 1713483460461, 'current-ts': 1713483461245, 'status': 'no'}]
# [{'value': None, 'ts': 1713483462555, 'current-ts': 1713483463333, 'status': 'no'}]
# [{'value': None, 'ts': 1713483464659, 'current-ts': 1713483465438, 'status': 'no'}]
# [{'value': None, 'ts': 1713483466748, 'current-ts': 1713483467526, 'status': 'no'}]
# [{'value': None, 'ts': 1713483468850, 'current-ts': 1713483469629, 'status': 'no'}]
# [{'value': None, 'ts': 1713483471151, 'current-ts': 1713483471929, 'status': 'no'}]
# [{'value': None, 'ts': 1713483473244, 'current-ts': 1713483474026, 'status': 'no'}]
# [{'value': None, 'ts': 1713483475350, 'current-ts': 1713483476131, 'status': 'no'}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 142
#     140 if __name__ == "__main__":
#     141     while True:
# --> 142         main()
#
# Cell In[17], line 136, in main()
#     134         print(f"Sensor node is offline with {ip_address} and restarted")
#     135         logging.info(f"{ip_address} is restarted")
# --> 136 time.sleep(2)
#
# KeyboardInterrupt:

# %%
data = {"ip_address": [{"ts": 1713481792973, "value": None}]}

# Iterate over the list associated with the key "ip_address"
for ip_info in data.get("ip_address", []):
    # Access the 'ts' and 'value' keys for each dictionary in the list
    ts = ip_info.get("ts", 0)
    value = ip_info.get("value")
    print("Timestamp:", ts)
    print("Value:", value)
# Out:
# Timestamp: 1713481792973
# Value: None

# %% [markdown]
# my script.py code

# %%
# script.py

import requests
import time
import json
import subprocess
import logging
import os
from flask import Flask, render_template_string

logging.basicConfig(
    filename="curl_logs.txt", level=logging.INFO, format="%(asctime)s - %(message)s"
)

app = Flask(__name__)


@app.route("/logs")
def serve_logs():
    # Read logs from curl_logs.txt file
    with open("curl_logs.txt", "r") as f:
        logs = f.readlines()

    # Display the latest 50 logs
    logs = logs[-50:]

    # Render logs in HTML template
    html = "<h1>Latest Logs</h1><ul>"
    for log in logs:
        html += f"<li>{log}</li>"
    html += "</ul>"

    return html


def main():
    url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
    headers = {"Content-Type": "application/json"}

    payload = {
        "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
        "password": "SuhasDevmane",
    }

    response = requests.post(url, json=payload, headers=headers)

    if response.status_code == 200:
        # Authentication successful
        token = response.json().get("token")
        # print("JWT_Token:", token)
    else:
        logging.error("Authentication failed. Status Code:", response.status_code)
        logging.error("Response:", response.text)

    # Get current timestamp in Unix format with milliseconds
    current_timestamp = int(time.time() * 1000)
    # print("Current timestamp (Unix format with milliseconds):", current_timestamp)
    device_ids = [
        "70ad22a0-b82c-11ed-b196-bb47e24272bc",
        "75d29440-b82c-11ed-b196-bb47e24272bc",
        "7b717ba0-b82c-11ed-b196-bb47e24272bc",
        "a673eb80-b82c-11ed-b196-bb47e24272bc",
        "83456b70-b82c-11ed-b196-bb47e24272bc",
        "b96d6720-b82c-11ed-b196-bb47e24272bc",
        "be98a520-b82c-11ed-b196-bb47e24272bc",
        "c3110de0-b82c-11ed-b196-bb47e24272bc",
        "c950f030-b82c-11ed-b196-bb47e24272bc",
        "cfddba00-b82c-11ed-b196-bb47e24272bc",
        "278505c0-0f7a-11ee-bf90-a16a1a9e1e0a",
        "d9576a90-b82c-11ed-b196-bb47e24272bc",
        "de18ea40-b82c-11ed-b196-bb47e24272bc",
        "f57a1560-7cf3-11ee-94bc-d389020903a3",
        "508d1b60-57eb-11ee-8714-19d56ba0c4fd",
        "86c63bd0-57f0-11ee-8714-19d56ba0c4fd",
        "3efd82d0-7cf4-11ee-94bc-d389020903a3",
        "f583bc50-57e6-11ee-8714-19d56ba0c4fd",
        "9458c560-0f75-11ee-bf90-a16a1a9e1e0a",
        "cbc851c0-57ee-11ee-8714-19d56ba0c4fd",
        "2ae959b0-53c6-11ee-8714-19d56ba0c4fd",
        "351b0eb0-57ef-11ee-8714-19d56ba0c4fd",
        "0f96bed0-b82d-11ed-b196-bb47e24272bc",
        "13e642d0-b82d-11ed-b196-bb47e24272bc",
        "18a159e0-b82d-11ed-b196-bb47e24272bc",
        "fef50770-57f1-11ee-8714-19d56ba0c4fd",
        "2a5d9a90-b82d-11ed-b196-bb47e24272bc",
        "99c6a3b0-b82b-11ed-b196-bb47e24272bc",
        "51f2d170-57e1-11ee-8714-19d56ba0c4fd",
        "9c563630-0f75-11ee-bf90-a16a1a9e1e0a",
        "391303e0-b82d-11ed-b196-bb47e24272bc",
        "3d3a3f60-b82d-11ed-b196-bb47e24272bc",
        "a83a46c0-7cf4-11ee-94bc-d389020903a3",
        "4665a8e0-b82d-11ed-b196-bb47e24272bc",
    ]
    access_token = token
    key_to_fetch = ["ip_address"]
    base_url = "https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE"

    # List to store responses for each device
    all_responses = []

    for device_id in device_ids:
        url = f"{base_url}/{device_id}/values/timeseries?keys={','.join(key_to_fetch)}"
        headers = {
            "Content-Type": "application/json",
            "X-Authorization": f"Bearer {access_token}",
        }
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
        else:
            logging.error(
                f"Failed to get data for device {device_id}. Status Code: {response.status_code}"
            )
            logging.error(response.text)
            continue
        current_timestamp = int(
            time.time() * 1000
        )  # Get current timestamp in milliseconds
        results = []
        # Iterate over the list associated with the key "ip_address"
        for ip_info in data.get("ip_address", []):
            # Access the 'ts' and 'value' keys for each dictionary in the list
            ts = ip_info.get("ts", 0)
            value = ip_info.get("value")
            # print("Timestamp:", ts)
            # print("Value:", value)
            time_diff = (
                current_timestamp - ts
            ) / 1000  # Convert milliseconds to seconds

            status = "yes" if time_diff > 120 else "no"
            if value is None:
                status = "no"

            result = {
                "value": value,
                "ts": ts,
                "current-ts": current_timestamp,
                "status": status,
            }
            results.append(result)
            print(results)
            for result in results:
                if result["status"] == "yes":
                    ip_address = result["value"]
                    url = "http://probable-goshawk-accurately.ngrok-free.app/device_activity"
                    payload = {
                        "ip_address": ip_address
                    }  # Removed unnecessary curly braces around ip_address
                    headers = {
                        "Content-Type": "application/json"
                    }  # Assuming you have headers defined somewhere
                    response = requests.post(url, json=payload, headers=headers)
                    time.sleep(5)
                    print(response.text)
                    print(f"Sensor node is offline with {ip_address} and restarted")
                    logging.info(f"{ip_address} is restarted")
            time.sleep(5)


def run_flask():
    # Start the Flask application with Gunicorn
    subprocess.run(["gunicorn", "-b", "0.0.0.0:5001", "script:app"])


if __name__ == "__main__":
    # Create a thread to run the Flask application
    import threading

    flask_thread = threading.Thread(target=run_flask)
    flask_thread.start()

    while True:
        token = main()
        time.sleep(15)
